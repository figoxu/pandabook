# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add("",  [list(z) for z in zip(["语文","数学","英语","综合"],[150, 150, 150, 300])])
    .set_colors(["blue", "green", "#FF00FF", "#FFBF00"])
    .set_global_opts(title_opts=opts.TitleOpts(title="高考科目分数占比"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="29f556aa61214dc0b09e376663d4990c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_29f556aa61214dc0b09e376663d4990c = echarts.init(
#                     document.getElementById('29f556aa61214dc0b09e376663d4990c'), 'white', {renderer: 'canvas'});
#                 var option_29f556aa61214dc0b09e376663d4990c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "green",
#         "#FF00FF",
#         "#FFBF00"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8bed\u6587",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u6570\u5b66",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u82f1\u8bed",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u7efc\u5408",
#                     "value": 300
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8bed\u6587",
#                 "\u6570\u5b66",
#                 "\u82f1\u8bed",
#                 "\u7efc\u5408"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u9ad8\u8003\u79d1\u76ee\u5206\u6570\u5360\u6bd4",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_29f556aa61214dc0b09e376663d4990c.setOption(option_29f556aa61214dc0b09e376663d4990c);
#         });
#     </script>

# %%
import pandas as pd
path = "./data/分数线.csv" 

score = pd.read_csv(path)
score["文理分科"]=score["文理分科 "]
lk = score[(score["文理分科"]=="理科")]
wk = score[(score["文理分科"]=="文科")]
lk.columns
# Out:
# Index(['年份 ', '考生所在地 ', '文理分科 ', '本科一批 ', '本科二批', '文理分科'], dtype='object')

# %%
year_list = lk["年份 "]
lk_1 = lk["本科一批 "]
lk_2 = lk["本科二批"]

scoreLine = (
    Line(init_opts=opts.InitOpts(width="800px", height="400px"))
    .set_colors(["blue",  "#FF00FF"])
    .add_xaxis(xaxis_data=year_list)
    .add_yaxis(
        series_name="理科一批",
        y_axis=lk_1,
    )
    .add_yaxis(
        series_name="理科二批",
        y_axis=lk_2
    )
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(
            is_show=True, trigger="axis", axis_pointer_type="cross"
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            axispointer_opts=opts.AxisPointerOpts(is_show=True, type_="shadow"),
        ),
        yaxis_opts=opts.AxisOpts(
            name="北京高考理科分数线",
            type_="value",
            min_=400,
            max_=600,
            interval=10,
            axislabel_opts=opts.LabelOpts(formatter="{value} 分"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
)
scoreLine.render_notebook()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6af17574752f> in <module>
#       4
#       5 scoreLine = (
# ----> 6     Line(init_opts=opts.InitOpts(width="800px", height="400px"))
#       7     .set_colors(["blue",  "#FF00FF"])
#       8     .add_xaxis(xaxis_data=year_list)
#
# NameError: name 'Line' is not defined

# %%
list(lk_1)
# Out:
# [494, 484, 477, 550, 543, 548, 548, 537, 532, 527]

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar(init_opts=opts.InitOpts(width="800px", height="400px"))
    .set_colors(["#a1c84f","#42b0cd"])
    .add_xaxis(list(year_list))
    .add_yaxis( "理科二批", list(lk_2), stack="stack1" )
    .add_yaxis( "理科一批", list(lk_1-lk_2), stack="stack1" )
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            name="北京高考理科分数线",
            axislabel_opts=opts.LabelOpts(formatter="{value} 分"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5103d5d52ad34d2caf91ce7a4636b88d" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5103d5d52ad34d2caf91ce7a4636b88d = echarts.init(
#                     document.getElementById('5103d5d52ad34d2caf91ce7a4636b88d'), 'white', {renderer: 'canvas'});
#                 var option_5103d5d52ad34d2caf91ce7a4636b88d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#a1c84f",
#         "#42b0cd"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7406\u79d1\u4e8c\u6279",
#             "data": [
#                 441,
#                 435,
#                 433,
#                 505,
#                 495,
#                 495,
#                 494,
#                 438,
#                 432,
#                 423
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7406\u79d1\u4e00\u6279",
#             "data": [
#                 53,
#                 49,
#                 44,
#                 45,
#                 48,
#                 53,
#                 54,
#                 99,
#                 100,
#                 104
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7406\u79d1\u4e8c\u6279",
#                 "\u7406\u79d1\u4e00\u6279"
#             ],
#             "selected": {
#                 "\u7406\u79d1\u4e8c\u6279": true,
#                 "\u7406\u79d1\u4e00\u6279": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2104,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5317\u4eac\u9ad8\u8003\u7406\u79d1\u5206\u6570\u7ebf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} \u5206"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5103d5d52ad34d2caf91ce7a4636b88d.setOption(option_5103d5d52ad34d2caf91ce7a4636b88d);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar(init_opts=opts.InitOpts(width="800px", height="400px"))
    .set_colors(["#a1c84f","#42b0cd"])
    .add_xaxis(list(year_list))
    .add_yaxis( "文科二批", list(wk_2), stack="stack1" )
    .add_yaxis( "文科一批", list(wk_1-wk_2), stack="stack1" )
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            name="北京高考文科分数线",
            axislabel_opts=opts.LabelOpts(formatter="{value} 分"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
            is_inverse=False,
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="18ce3ea77bb04c0090a08d494d3d1ea4" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_18ce3ea77bb04c0090a08d494d3d1ea4 = echarts.init(
#                     document.getElementById('18ce3ea77bb04c0090a08d494d3d1ea4'), 'white', {renderer: 'canvas'});
#                 var option_18ce3ea77bb04c0090a08d494d3d1ea4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#a1c84f",
#         "#42b0cd"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6587\u79d1\u4e8c\u6279",
#             "data": [
#                 474,
#                 481,
#                 446,
#                 494,
#                 507,
#                 527,
#                 532,
#                 468,
#                 488,
#                 480
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6587\u79d1\u4e00\u6279",
#             "data": [
#                 50,
#                 43,
#                 49,
#                 55,
#                 58,
#                 52,
#                 51,
#                 87,
#                 88,
#                 79
#             ],
#             "stack": "stack1",
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6587\u79d1\u4e8c\u6279",
#                 "\u6587\u79d1\u4e00\u6279"
#             ],
#             "selected": {
#                 "\u6587\u79d1\u4e8c\u6279": true,
#                 "\u6587\u79d1\u4e00\u6279": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2104,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5317\u4eac\u9ad8\u8003\u6587\u79d1\u5206\u6570\u7ebf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} \u5206"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_18ce3ea77bb04c0090a08d494d3d1ea4.setOption(option_18ce3ea77bb04c0090a08d494d3d1ea4);
#         });
#     </script>

# %%
c = (
    Bar(init_opts=opts.InitOpts(width="800px", height="550px"))
    .set_colors(["#a1c84f","#42b0cd"])
    .add_xaxis(list(year_list))
    .add_yaxis( "理科二批", list(lk_2)  )
    .add_yaxis( "理科一批", list(lk_1) )
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            name="北京高考理科分数线",
            axislabel_opts=opts.LabelOpts(formatter="{value} 分"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a9e063b5d0c340adb136fff6f2022556" style="width:800px; height:550px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a9e063b5d0c340adb136fff6f2022556 = echarts.init(
#                     document.getElementById('a9e063b5d0c340adb136fff6f2022556'), 'white', {renderer: 'canvas'});
#                 var option_a9e063b5d0c340adb136fff6f2022556 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#a1c84f",
#         "#42b0cd"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7406\u79d1\u4e8c\u6279",
#             "data": [
#                 441,
#                 435,
#                 433,
#                 505,
#                 495,
#                 495,
#                 494,
#                 438,
#                 432,
#                 423
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7406\u79d1\u4e00\u6279",
#             "data": [
#                 494,
#                 484,
#                 477,
#                 550,
#                 543,
#                 548,
#                 548,
#                 537,
#                 532,
#                 527
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7406\u79d1\u4e8c\u6279",
#                 "\u7406\u79d1\u4e00\u6279"
#             ],
#             "selected": {
#                 "\u7406\u79d1\u4e8c\u6279": true,
#                 "\u7406\u79d1\u4e00\u6279": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5317\u4eac\u9ad8\u8003\u7406\u79d1\u5206\u6570\u7ebf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} \u5206"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2104,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a9e063b5d0c340adb136fff6f2022556.setOption(option_a9e063b5d0c340adb136fff6f2022556);
#         });
#     </script>

# %%
c = (
    Bar(init_opts=opts.InitOpts(width="800px", height="550px"))
    .set_colors(["#a1c84f","#42b0cd"])
    .add_xaxis(list(year_list))
    .add_yaxis( "文科二批", list(wk_2)  )
    .add_yaxis( "文科一批", list(wk_1) )
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(
        yaxis_opts=opts.AxisOpts(
            name="北京高考文科分数线",
            axislabel_opts=opts.LabelOpts(formatter="{value} 分"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8b6e0ef91b0a4491968485dc82d5705d" style="width:800px; height:550px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8b6e0ef91b0a4491968485dc82d5705d = echarts.init(
#                     document.getElementById('8b6e0ef91b0a4491968485dc82d5705d'), 'white', {renderer: 'canvas'});
#                 var option_8b6e0ef91b0a4491968485dc82d5705d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#a1c84f",
#         "#42b0cd"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6587\u79d1\u4e8c\u6279",
#             "data": [
#                 474,
#                 481,
#                 446,
#                 494,
#                 507,
#                 527,
#                 532,
#                 468,
#                 488,
#                 480
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6587\u79d1\u4e00\u6279",
#             "data": [
#                 524,
#                 524,
#                 495,
#                 549,
#                 565,
#                 579,
#                 583,
#                 555,
#                 576,
#                 559
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6587\u79d1\u4e8c\u6279",
#                 "\u6587\u79d1\u4e00\u6279"
#             ],
#             "selected": {
#                 "\u6587\u79d1\u4e8c\u6279": true,
#                 "\u6587\u79d1\u4e00\u6279": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u5317\u4eac\u9ad8\u8003\u6587\u79d1\u5206\u6570\u7ebf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} \u5206"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2104,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8b6e0ef91b0a4491968485dc82d5705d.setOption(option_8b6e0ef91b0a4491968485dc82d5705d);
#         });
#     </script>

# %%
from pyecharts import __version__
__version__
# Out:
# '1.7.1'

# %%
year_list = lk["年份 "]
wk_1 = wk["本科一批 "]
wk_2 = wk["本科二批"]


scoreLine = (
    Line(init_opts=opts.InitOpts(width="800px", height="400px"))
    .set_colors(["#425d0b","#42b0cd"])
    .add_xaxis(xaxis_data=year_list)
    .add_yaxis(
        series_name="文科一批",
        y_axis=wk_1,
    )
    .add_yaxis(
        series_name="文科二批",
        y_axis=wk_2
    )
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(
            is_show=True, trigger="axis", axis_pointer_type="cross"
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            axispointer_opts=opts.AxisPointerOpts(is_show=True, type_="shadow"),
        ),
        yaxis_opts=opts.AxisOpts(
            name="北京高考文科分数线",
            type_="value",
            min_=400,
            max_=600,
            interval=10,
            axislabel_opts=opts.LabelOpts(formatter="{value} 分"),
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
)
scoreLine.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fc1bb28a5fb54f7893e8ec08ec8f4426" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fc1bb28a5fb54f7893e8ec08ec8f4426 = echarts.init(
#                     document.getElementById('fc1bb28a5fb54f7893e8ec08ec8f4426'), 'white', {renderer: 'canvas'});
#                 var option_fc1bb28a5fb54f7893e8ec08ec8f4426 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#425d0b",
#         "#42b0cd"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6587\u79d1\u4e00\u6279",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     524
#                 ],
#                 [
#                     2011,
#                     524
#                 ],
#                 [
#                     2012,
#                     495
#                 ],
#                 [
#                     2013,
#                     549
#                 ],
#                 [
#                     2104,
#                     565
#                 ],
#                 [
#                     2015,
#                     579
#                 ],
#                 [
#                     2016,
#                     583
#                 ],
#                 [
#                     2017,
#                     555
#                 ],
#                 [
#                     2018,
#                     576
#                 ],
#                 [
#                     2019,
#                     559
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6587\u79d1\u4e8c\u6279",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     2010,
#                     474
#                 ],
#                 [
#                     2011,
#                     481
#                 ],
#                 [
#                     2012,
#                     446
#                 ],
#                 [
#                     2013,
#                     494
#                 ],
#                 [
#                     2104,
#                     507
#                 ],
#                 [
#                     2015,
#                     527
#                 ],
#                 [
#                     2016,
#                     532
#                 ],
#                 [
#                     2017,
#                     468
#                 ],
#                 [
#                     2018,
#                     488
#                 ],
#                 [
#                     2019,
#                     480
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6587\u79d1\u4e00\u6279",
#                 "\u6587\u79d1\u4e8c\u6279"
#             ],
#             "selected": {
#                 "\u6587\u79d1\u4e00\u6279": true,
#                 "\u6587\u79d1\u4e8c\u6279": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisPointer": {
#                 "show": true,
#                 "type": "shadow"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": null
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "name": "\u5317\u4eac\u9ad8\u8003\u6587\u79d1\u5206\u6570\u7ebf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "interval": 10,
#             "gridIndex": 0,
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} \u5206"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 400,
#             "max": 600,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_fc1bb28a5fb54f7893e8ec08ec8f4426.setOption(option_fc1bb28a5fb54f7893e8ec08ec8f4426);
#         });
#     </script>

# %%
import pandas as pd
path = "./data/高考.csv" 
exame = pd.read_csv(path)
exame["高考人数"] = exame["高考人数 "].str.replace("万", "")
exame["高考人数"] = exame["高考人数"].astype("int")
exame["录取率"] = exame["录取率"].str.replace("%", "")
exame["录取率"] = exame["录取率"].astype("float")


exame["录取人数"] = exame["录取人数"].str.replace("万", "")
exame["录取人数"] = exame["录取人数"].astype("float")
exame["录取人数"] = exame["录取人数"].astype("int")

exame = exame.sort_values(by=['年份'],ascending=True)
exame
# Out:
#      年份  高考人数   录取人数    录取率  高考人数
# 9  2010   946万   657  69.00   946
# 8  2011   933万   675  72.00   933
# 7  2012   915万   685  75.00   915
# 6  2013   912万   694  76.00   912
# 5  2014   939万   698  74.30   939
# 4  2015   942万   700  74.30   942
# 3  2016   940万   705  75.00   940
# 2  2017   940万   700  74.46   940
# 1  2018   975万   790  81.13   975
# 0  2019  1031万   820  79.53  1031

# %% [markdown]
# from pyecharts import options as opts
# from pyecharts.charts import Bar, Line
#
# x_data = exame["年份"].apply(str).tolist()
# bar = (
#     Bar(init_opts=opts.InitOpts(width="1000px", height="400px"))
#     .add_xaxis(
#        x_data
#     )
#     .set_colors(["#a1c84f","#42b0cd","#2c4d75"])
#     .add_yaxis(series_name="高考人数(单位: 万人)",yaxis_data= exame["高考人数"].tolist(),
#  yaxis_index=0, color="#a1c84f")
#     .add_yaxis("录取人数(单位: 万人)", exame["录取人数"].tolist(), color="#42b0cd")
#     .extend_axis(
#         yaxis=opts.AxisOpts(
#             name="录取率",
#             type_="value",
#             min_=0,
#             max_=100,
#             interval=10,
#             axislabel_opts=opts.LabelOpts(formatter="{value} %"),
#         )
#     )
#     .set_global_opts(
#         tooltip_opts=opts.TooltipOpts(
#             is_show=True, trigger="axis", axis_pointer_type="cross"
#         ),
#         xaxis_opts=opts.AxisOpts(
#             type_="category",
#             axispointer_opts=opts.AxisPointerOpts(is_show=True, type_="shadow"),
#         ),
#         yaxis_opts=opts.AxisOpts(
#             name="人数",
#             type_="value",
#             min_=500,
#             max_=1400,
#             interval=100,
#             axislabel_opts=opts.LabelOpts(formatter="{value} 万人"),
#             axistick_opts=opts.AxisTickOpts(is_show=True),
#             splitline_opts=opts.SplitLineOpts(is_show=True),
#         ),
#     )
# )
#
#
# x_data = exame["年份"].apply(str).tolist()
# y_data = exame["录取率"].tolist()
# line = (
#     Line()
#     .add_xaxis(x_data)
#     .set_colors(["#2c4d75"])
#     .add_yaxis(series_name="录取率",
#         yaxis_index=1,
#                y_axis=exame["录取率"], color="#2c4d75",
#               label_opts=opts.LabelOpts(is_show=True),)
#
# )
#
# bar.overlap(line).render_notebook()
#
# # charts相关API参考 https://gallery.pyecharts.org/#/Line/multiple_x_axes
